# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %pylab inline
pylab.rcParams['figure.figsize'] = (18, 10)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Load and clean the data a little 
data = pd.read_csv("searchLog.csv")
data.drop_duplicates(inplace = True)
data.rename(columns = lambda x: x.strip(), inplace = True)
data.rename(columns = lambda x: x.lower(), inplace = True)
data[data.select_dtypes(['object']plt.grid(True,which="both",alpha = 0.5)).columns] = data.select_dtypes(['object']).apply(lambda x: x.str.strip())
data.drop(data[data['heuristic'] == 'Random'].index,inplace=True)
data.replace('z', '', regex=True, inplace=True)
data.to_csv("searchLog.csv",index=False)
data.tail()
# Out:
#                       algorithm        heuristic        problem  \
# 83             Forward Checking             Name  FinnishSudoku
# 86             Forward Checking        MaxDegree  FinnishSudoku
# 87  Maintaining Arc Consistency  Smallest Domain  FinnishSudoku
# 88  Maintaining Arc Consistency             Name  FinnishSudoku
# 89  Maintaining Arc Consistency        MaxDegree  FinnishSudoku
#
#     branches explored  arcs revised  number of vars  number of constraints
# 83            3027747       7816364              81                    810
# 86             218711        537743              81                    810
# 87               4211         55013              81                    810
# 88               9805         89290              81                    810
# 89               1313          7692              81                    810

# %%
# Calculate some additional measurements and prepare the data for plotting
data['branch per constraint'] = data['branches explored']/data['number of constraints']
data['branch per variable'] = data['branches explored']/data['number of vars']
data['algorithm'] = data['algorithm'] + "+" + data['heuristic']
data.drop('heuristic',axis=1,inplace=True)
data.head()
# Out:
#                      algorithm        heuristic   problem  branches explored  \
# 0                 Backtracking             None  10Queens                975
# 1             Forward Checking  Smallest Domain  10Queens                292
# 2             Forward Checking             Name  10Queens                150
# 4             Forward Checking        MaxDegree  10Queens                150
# 5  Maintaining Arc Consistency  Smallest Domain  10Queens                 54
#
#    arcs revised  number of vars  number of constraints  branch per constraint  \
# 0             0              10                     45              21.666667
# 1           517              10                     45               6.488889
# 2           215              10                     45               3.333333
# 4           215              10                     45               3.333333
# 5           315              10                     45               1.200000
#
#    branch per variable
# 0                 97.5
# 1                 29.2
# 2                 15.0
# 4                 15.0
# 5                  5.4

# %%
# Plot the grouped data
g = sns.barplot(x='problem',y='branches explored',data=datah,hue='algorithm',
               order=['4Queens','6Queens','8Queens','10Queens',
                      'langfords2_3','langfords2_4','langfords3_9','langfords3_10',
                      'SimonisSudoku','FinnishSudoku',])
g.set_yscale('log')
plt.grid(True,which="both",alpha = 0.5)
# Out:
# /cs/home/dav/Documents/workdir/CS4144/python/lib64/python3.6/site-packages/matplotlib/scale.py:111: RuntimeWarning: invalid value encountered in less_equal
#   out[a <= 0] = -1000
