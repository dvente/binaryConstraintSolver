# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import Series, DataFrame
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 7)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv("../dataAnalysis/searchLog.csv")
data.drop_duplicates(inplace = True)
data.rename(columns=lambda x: x.strip(),inplace=True)
data.head()
# Out:
#           Algorithm         Heuristic    Problem  Nodes explored  \
# 0      Backtracking              None   10Queens             975
# 1  Forward Checking   Smallest Domain   10Queens             292
# 2  Forward Checking              Name   10Queens             150
# 3  Forward Checking            Random   10Queens              12
# 4  Forward Checking         MaxDegree   10Queens              12
#
#    Arcs Revised  Variables in problem  Constraints in problem
# 0             0                    10                      45
# 1           517                    10                      45
# 2           215                    10                      45
# 3            40                    10                      45
# 4            40                    10                      45

# %%
data['Branch Per Constraint'] = data['Nodes explored']/data['Constraints in problem']
data['Branch Per Variable'] = data['Nodes explored']/data['Variables in problem']

# %%
data.head()
# Out:
#           Algorithm         Heuristic    Problem  Nodes explored  \
# 0      Backtracking              None   10Queens             975
# 1  Forward Checking   Smallest Domain   10Queens             292
# 2  Forward Checking              Name   10Queens             150
# 3  Forward Checking            Random   10Queens              12
# 4  Forward Checking         MaxDegree   10Queens              12
#
#    Arcs Revised  Variables in problem  Constraints in problem  \
# 0             0                    10                      45
# 1           517                    10                      45
# 2           215                    10                      45
# 3            40                    10                      45
# 4            40                    10                      45
#
#    Branch Per Constraint  Branch Per Variable
# 0              21.666667                 97.5
# 1               6.488889                 29.2
# 2               3.333333                 15.0
# 3               0.266667                  1.2
# 4               0.266667                  1.2

# %%
#Taken from https://stackoverflow.com/questions/15465645/plotting-results-of-pandas-groupby#15466103
for key, grp in data.groupby(['Algorithm']):
    label =key
    plt.semilogy(grp['Variables in problem'],grp['Nodes explored'], label = label)
    plt.xlabel('Variables in problem')
    plt.xticks(range(data['Variables in problem'].min(),data['Variables in problem'].max()+1))
    plt.ylabel('Nodes Explored')
plt.legend(loc='best')

plt.grid(True, which="both")
plt.show()

# data.groupby('Algorithm').plot(x='Variables in problem',y='Nodes explored')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Nodes Explored'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-0473e407787f> in <module>()
#       2 for key, grp in data.groupby(['Algorithm']):
#       3     label =key
# ----> 4     plt.semilogy(grp['Variables in problem'],grp['Nodes Explored'], label = label)
#       5     plt.xlabel('Variables in problem')
#       6     plt.xticks(range(data['Variables in problem'].min(),data['Variables in problem'].max()+1))
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Nodes Explored'
